# %%
import math
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import sklearn.datasets

# %%
np.random.seed(12)
num_observations = 50

x1 = np.random.multivariate_normal([-1, -1], [[1, .75],[.75, 1]], num_observations)
x2 = np.random.multivariate_normal([1, 4], [[1, .75],[.75, 1]], num_observations)

X = np.vstack((x1, x2)).astype(np.float32)
y = np.hstack((np.zeros(num_observations), np.ones(num_observations)))

#Displaying the output
plt.figure(figsize=(12,8))
plt.scatter(X[:, 0], X[:, 1],  alpha = .4)

# %% [markdown]
# #### (i) “Assigning” each training example x
# - (i) to the closest cluster centroid µj
# - (ii) Moving each cluster centroid µj to the mean of the points assigned to it.

# %%
def distance(centroids, x):
    return [math.sqrt(sum([(i[0]-i[1])**2 for i in list(zip(x, c))])) for c in centroids]

# %%
def max_idx(number_list):
    max_value = max(number_list)
    max_index = number_list.index(max_value)
    return max_index

# %% [raw]
# centroids = np.random.random(4).reshape((2, 2))
# i =0
#
# while i <= 100:
#     idx = np.array(list(map(lambda x: max_idx(distance(centroids, x)), X)))
#
#     group1 = X[np.where(idx>0)]
#     group2 = X[np.where(idx==0)]
#
#     c1 = np.apply_along_axis(lambda x: np.mean(x), 0, group1).reshape(1, 2)
#     c2 = np.apply_along_axis(lambda x: np.mean(x), 0, group2).reshape(1, 2)
#     centroids = np.append(c1, c2, axis =0)
#     i+=1

# %%
plt.figure(figsize=(12,8))
plt.scatter(X[:, 0], X[:, 1], c = idx, alpha = .4)

# %%
centroids
# Out:
# array([[-0.866365  , -0.87179995],
#        [ 1.410328  ,  4.2588353 ]], dtype=float32)

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=2, random_state=0).fit(X)

# %%
kmeans.cluster_centers_
# Out:
# array([[-0.86636513, -0.8718003 ],
#        [ 1.4103279 ,  4.258836  ]], dtype=float32)

# %%
plt.figure(figsize=(12,8))
plt.scatter(X[:, 0], X[:, 1], c = kmeans.labels_, alpha = .4)
